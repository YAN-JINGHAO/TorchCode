# %% [markdown]
# <a href="https://colab.research.google.com/github/YAN-JINGHAO/TorchCode/blob/main/templates/03_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/03_linear.ipynb)
#
# # 🟡 Medium: Simple Linear Layer
#
# Implement a fully-connected linear layer: **y = xW^T + b**
#
# ### Signature
# ```python
# class SimpleLinear:
#     def __init__(self, in_features: int, out_features: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - `self.weight`: shape `(out_features, in_features)`, init with `randn * (1/√in_features)`
# - `self.bias`: shape `(out_features,)`, init as zeros
# - Both must have `requires_grad=True`
# - `forward(x)` computes `x @ W^T + b`
# - Do **NOT** use `torch.nn.Linear`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.5 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class SimpleLinear:
    def __init__(self, in_features: int, out_features: int):
        # Initialize weight and bias
        self.weight = torch.nn.Parameter( # need grad
            torch.randn(out_features, in_features) / math.sqrt(in_features)
        )
        self.bias = torch.nn.Parameter( # need grad
            torch.zeros(out_features)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Compute y = x @ W^T + b
        return x @ self.weight.T + self.bias

# %%
in_features = 8
out_features = 4
W = torch.randn(out_features, in_features) / math.sqrt(in_features)
print(W)
# Out:
# tensor([[ 0.0063,  0.4158, -0.1620,  0.0178, -0.1019,  0.2016,  0.0859, -0.7152],
#         [-0.1294, -0.4199,  0.2413,  0.1068, -0.1473,  0.4708,  0.6311, -0.0256],
#         [ 0.0206, -0.4677, -0.5484,  0.1807,  0.0983,  0.1660,  0.5358, -0.0328],
#         [ 0.0024,  0.2262, -0.3772, -0.1130, -0.0816, -0.0988, -0.5335, -0.1020]])

# %%
b = torch.zeros(out_features)
print(b.shape)
# Out:
# torch.Size([4])

# %%
# 🧪 Debug
layer = SimpleLinear(8, 4)
print("W shape:", layer.weight.shape)  # should be (4, 8)
print("b shape:", layer.bias.shape)    # should be (4,)

x = torch.randn(2, 8)
y = layer.forward(x)
print("Output shape:", y.shape)        # should be (2, 4)
# Out:
# W shape: torch.Size([4, 8])
# b shape: torch.Size([4])
# Output shape: torch.Size([2, 4])

# %%
# ✅ SUBMIT
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ❌ [1/3] Weight & bias shape
#      weight must require grad
#   ✅ [2/3] Forward pass (12.0ms)
#   💥 [3/3] Gradient flow
#      RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
#          return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
# ──────────────────────────────────────────────────
#   📊 1/3 tests passed.
#   Keep going! Use hint("linear") if you're stuck.

# %%
# ✅ SUBMIT
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Weight & bias shape (0.5ms)
#   ✅ [2/3] Forward pass (2.6ms)
#   ✅ [3/3] Gradient flow (20.2ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (23.3ms total)
#   Progress saved. Run status() to see your dashboard.
